# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.linspace(-10,10,100)
plt.plot(x,1/(1+np.exp(-x))) #Sigmoid Funtion Used to predict the probability of the output

# %%
X=np.linspace()

# %%
# Linear Activation Function is used to predict the output of the model

# %%
plt.plot(x,x) #Linear Activation Function
#linear = turns the neural network into just one layer.range(0-infinity)

# %%
#Tanh Activation Function is used to predict the output of the model
##Tanh Function = Used to run the multi-layer neural networks,range [-1, 1].

# %%
plt.plot(x,np.tanh(x)) #Tanh Activation Function
plt.plot(np.exp(x))-np.exp-(x))/np.exp(x))+np.exp(-x))

# %%
plt.plot((np.exp(x)-np.exp(-x)) / (np.exp(x)+np.exp(-x)))

# %%
# Relu Activation function

# %%
plt.plot(x,np.maximum(0,x))

# %%
#Swish = function allows data normalization,range of(−∞,+∞)

# %%
plt.plot(x/(1+np.exp(-x)))

# %%
plt.plot(x-(np.tanh(x)))       #Tanh shrink= range(-1,1)
#The Tanhshrink activation function is indeed based on the hyperbolic tangent (tanh) function.
#It is designed to shrink the input towards zero. Mathematically, it can be represented as:
#f(x)=x−tanh(x)

# %%
# Softsign= useful for training neural networks.range(-1,1)

# %%
plt.plot(x / (np.abs(x) + 1))

# %%
#Binary Activation Function

# %%
plt.plot(x,np.where(x>=0,1,0),color='blue')

# %%
#Softplus Activation Function
#SoftPlus_Function = Used to ensures that the output is always positive.
#range=(0,+∞)

# %%
plt.plot(x,np.log(1 + np.exp(x)))

# %%
# Logarithmic function
#Logarithmic function= to apply nonlinear transformations to input data, solving complex problems.
#range(−∞,+∞).

# %%
plt.plot(np.log(x/(1-x)))
# Out:
# C:\Users\Prathamesh\AppData\Local\Temp\ipykernel_10184\2523006893.py:1: RuntimeWarning: invalid value encountered in log
#   plt.plot(np.log(x/(1-x)))
