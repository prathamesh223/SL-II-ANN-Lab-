# %% [markdown]
# Day: Wed, 24th April, 2024<br>
# Name: <b>SARTHAK KIRAN GIRME</b><br>
# Roll No.: 23370<b>16</b>
# # CNN Object Detection: Performance Metrics
# ## SL-2 Practical No. 10
#
# <b>Statment: </b><i> Write Python program to implement `CNN Object Detection`. Discuss numerous `Performance EevaluationMmetric`s for evaluating the object detecting algorithms' performance.</i>
# <hr>

# %% [markdown]
# ## Packages

# %%
# pip install tensorflow

# %%
# pip install scikit-learn

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from tensorflow.keras import datasets, models, layers

# %% [markdown]
# <hr>

# %% [markdown]
# ## Dataset: CIFAR10

# %%
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
(x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()   # this requires Internet for downloading

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1), (10000, 32, 32, 3), (10000, 1))

# %%
plt.figure(figsize=(12,5))
for i in range(10):
    plt.subplot(2,5,i+1)
    plt.imshow(x_train[i])
    plt.title(classes[y_train.reshape(-1,)[i]])

# %% [markdown]
# <hr>

# %% [markdown]
# ## Normalization: Min-Max

# %%
x_train[111].flatten()
# Out:
# array([135, 160, 179, ..., 139, 139, 140], dtype=uint8)

# %%
x_train = x_train/255.0
x_test  = x_test/255.0

# %%
x_train[111].flatten()
# Out:
# array([0.52941176, 0.62745098, 0.70196078, ..., 0.54509804, 0.54509804,
#        0.54901961])

# %% [markdown]
# <hr>

# %% [markdown]
# ## Graphs: Generic code

# %%
def Graphs(accuracy, loss, val_accuracy, val_loss, epochs):
    # Create a figure and axis object
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
    # Plot the first subplot (Training Accuracy)
    ax1.plot(epochs, accuracy, 'y', label='Training Accuracy')
    ax1.plot(epochs, val_accuracy, 'r', label='Validation Accuracy')
    ax1.set_title('Accuracy Graph')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend()
    # Plot the second subplot (Training Loss)
    ax2.plot(epochs, loss, 'y', label='Training Loss')
    ax2.plot(epochs, val_loss, 'r', label='Validation Loss')
    ax2.set_title('Loss Graph')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend()
    # Adjust layout
    plt.tight_layout()
    # Show the figure
    plt.show()

# %% [markdown]
# <hr>

# %% [markdown]
# ## Model Building

# %%
model = models.Sequential([
    layers.Conv2D(64, (3,3), activation='relu', input_shape=(32, 32, 3)),
    layers.Dropout(0.2),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(128, (4,4), activation='relu'),
    layers.Dropout(0.2),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(128, (4,4), activation='relu'),
    layers.Flatten(),
    layers.Dense(64 , activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(10, activation='softmax'),
])
# Out:
# C:\Users\Prathamesh\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# #### Model Training

# %%
history = model.fit(x_train, y_train, validation_split=0.2, batch_size= 32, epochs=10)
# Out:
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 42s 32ms/step - accuracy: 0.2889 - loss: 1.8874 - val_accuracy: 0.5223 - val_loss: 1.3836
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 37s 30ms/step - accuracy: 0.5253 - loss: 1.3212 - val_accuracy: 0.6006 - val_loss: 1.1920
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 37s 30ms/step - accuracy: 0.5918 - loss: 1.1523 - val_accuracy: 0.5823 - val_loss: 1.1790
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 40s 32ms/step - accuracy: 0.6429 - loss: 1.0097 - val_accuracy: 0.6707 - val_loss: 0.9460
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 39s 31ms/step - accuracy: 0.6814 - loss: 0.9263 - val_accuracy: 0.6858 - val_loss: 0.9051
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 40s 32ms/step - accuracy: 0.6994 - loss: 0.8563 - val_accuracy: 0.6901 - val_loss: 0.9042
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 38s 30ms/step - accuracy: 0.7235 - loss: 0.8010 - val_accuracy: 0.7091 - val_loss: 0.8426
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 38s 31ms/step - accuracy: 0.7403 - loss: 0.7498 - val_accuracy: 0.7109 - val_loss: 0.8364
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 37s 30ms/step - accuracy: 0.7587 - loss: 0.7025 - val_accuracy: 0.7160 - val_loss: 0.8216
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 38s 31ms/step - accuracy: 0.7630 - loss: 0.6795 - val_accuracy: 0.7067 - val_loss: 0.8449

# %%
Graphs(history.history['accuracy'], history.history['loss'], history.history['val_accuracy'], history.history['val_loss'], range(1, len(history.history['accuracy'])+1))

# %% [markdown]
# <hr>

# %% [markdown]
# ## Performance Evaluation

# %%
# On Test-Set
loss, accu = model.evaluate(x_test, y_test)
print('Accuracy: ',accu*100,'%')
print('Loss: ', loss)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.7069 - loss: 0.8683
# Accuracy:  70.95999717712402 %
# Loss:  0.867641806602478

# %% [markdown]
# #### Classification Report: on Test-Set

# %%
prob = model.predict(x_test)
predi = [np.argmax(i) for i in prob]
print(classification_report(y_test, predi))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step
#               precision    recall  f1-score   support
#
#            0       0.79      0.72      0.75      1000
#            1       0.92      0.77      0.84      1000
#            2       0.64      0.56      0.60      1000
#            3       0.54      0.48      0.51      1000
#            4       0.55      0.82      0.65      1000
#            5       0.60      0.64      0.62      1000
#            6       0.71      0.83      0.76      1000
#            7       0.82      0.70      0.76      1000
#            8       0.83      0.81      0.82      1000
#            9       0.83      0.77      0.80      1000
#
#     accuracy                           0.71     10000
#    macro avg       0.72      0.71      0.71     10000
# weighted avg       0.72      0.71      0.71     10000

# %% [markdown]
# <hr>

# %% [markdown]
# ## Save Model: CIFAR10

# %%
model.save('C10.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Object Detection

# %%
model = models.load_model('C10.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
def ObjectDetection(threshold):
    path = str(input('Enter path of Image: '))
    img  = tf.io.read_file(path)
    img  = tf.image.decode_jpeg(img, channels=3)
    plt.imshow(img)
    img  = tf.image.resize(img, [32,32])
    img  = img / 255.0
    img  = tf.expand_dims(img, axis=0)
    # Model: Object Detection
    probabilities = model.predict(img)
    class_indices = [i for i, prob in enumerate(probabilities.reshape(-1,)) if prob>=threshold]
    label= [classes[i] for i in class_indices]
    print(f"\u2022 Detected Objects: {label}")

# %%
ObjectDetection(0.5)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# • Detected Objects: ['truck']

# %%
ObjectDetection(0.1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# • Detected Objects: ['dog', 'frog']

# %%
ObjectDetection(0.09)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 ObjectDetection(0.09)
#
# Cell In[20], line 3, in ObjectDetection(threshold)
#       1 def ObjectDetection(threshold):
#       2     path = str(input('Enter path of Image: '))
# ----> 3     img  = tf.io.read_file(path)
#       4     img  = tf.image.decode_jpeg(img, channels=3)
#       5     plt.imshow(img)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\ops\io_ops.py:134, in read_file(filename, name)
#      97 @tf_export("io.read_file", v1=["io.read_file", "read_file"])
#      98 def read_file(filename, name=None):
#      99   """Reads the contents of file.
#     100
#     101   This operation returns a tensor with the entire contents of the input
#    (...)
#     132     A tensor of dtype "string", with the file contents.
#     133   """
# --> 134   return gen_io_ops.read_file(filename, name)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\ops\gen_io_ops.py:583, in read_file(filename, name)
#     581   pass
#     582 try:
# --> 583   return read_file_eager_fallback(
#     584       filename, name=name, ctx=_ctx)
#     585 except _core._SymbolicException:
#     586   pass  # Add nodes to the TensorFlow graph.
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\ops\gen_io_ops.py:606, in read_file_eager_fallback(filename, name, ctx)
#     604 _inputs_flat = [filename]
#     605 _attrs = None
# --> 606 _result = _execute.execute(b"ReadFile", 1, inputs=_inputs_flat,
#     607                            attrs=_attrs, ctx=ctx, name=name)
#     608 if _execute.must_record_gradient():
#     609   _execute.record_gradient(
#     610       "ReadFile", _inputs_flat, _attrs, _result)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# NotFoundError: {{function_node __wrapped__ReadFile_device_/job:localhost/replica:0/task:0/device:CPU:0}} NewRandomAccessFile failed to Create/Open:  : The system cannot find the file specified.
# ; No such file or directory [Op:ReadFile]

# %% [markdown]
# <hr>
